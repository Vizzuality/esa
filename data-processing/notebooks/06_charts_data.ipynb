# %% [markdown]
# # Prepare charts data
#
# This notebook is used to process the data provided for the charts in the way that Strapi needs it.

# %% [markdown]
# ## Set up
#
# ### Library import

# %%
import sys

sys.path.append("../src")
from data_processing.utils import csv_to_json

# %% [markdown]
# ## Process data

# %%
json_data = csv_to_json(
    input_file="../data/raw/Water/Zambezi/Transect_Kafue_River_chlorophyll_v2.csv",
    output_file="../data/raw/Water/Zambezi/Transect_Kafue_River_chlorophyll_v2.json",
    skiprows=4,
    sep=";"
)
